# %%
print("hello")
# Out:
# hello

# %%
from skimage import io
photo=io.imread('download.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (197, 256, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[50:150,150:200])
#crop image

# %%
plt.imshow(photo[::2,::2])
#reduce the size of image by half

# %%
import numpy as np
photo
photo_sin =np.sin(photo)
photo_sin
# Out:
# array([[[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]],
#
#        [[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]],
#
#        [[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]],
#
#        ...,
#
#        [[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]],
#
#        [[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]],
#
#        [[-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         ...,
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063],
#         [-0.5063, -0.5063, -0.5063]]], dtype=float16)

# %%
z=np.array([1,2,3,4,5])
z
# Out:
# array([1, 2, 3, 4, 5])

# %%
z>3
# Out:
# array([False, False, False,  True,  True])
